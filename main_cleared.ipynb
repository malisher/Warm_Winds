# %%
import xml.etree.ElementTree as ET
import openpyxl

folder_name = '792_annotations'
file_path = f'data/{folder_name}/annotations.xml'

filtered_brands = openpyxl.load_workbook(f'data/{folder_name}/filtered.xlsx')
filtered_brands_active = filtered_brands.active
brands = [cell.value.lower() for cell in filtered_brands_active['A'] if cell.value is not None]

tree = ET.parse(file_path)
root = tree.getroot()

images_data = []
points, bboxes = [], []
for child in root:
    if child.tag == 'image':
        box = [subchild.attrib for subchild in child if subchild.tag == 'box']
        point = [subchild.attrib for subchild in child if subchild.tag == 'points']
        element_info = {
            'tag': child.tag,
            'attributes': child.attrib,
            'children': {'box': box, 'points': point}
        }
        images_data.append(element_info)

# for child in root:
#     if child.tag == 'image':
#         box = [subchild.attrib for subchild in child if subchild.tag == 'box' and subchild.attrib.get('label') in brands]
#         if box:
#             point = [subchild.attrib for subchild in child if subchild.tag == 'points']
#             element_info = {
#                 'tag': child.tag,
#                 'attributes': child.attrib,
#                 'children': {'box': box, 'points': point}
#             }
#             images_data.append(element_info)

# %%
len(images_data)
# Out:
# 461

# %%
images_data[0]
# Out:
# {'tag': 'image',
#  'attributes': {'id': '0',
#   'name': '-3avTAO79w.jpg',
#   'width': '1125',
#   'height': '2000'},
#  'children': {'box': [{'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '285.00',
#     'ytl': '463.00',
#     'xbr': '356.00',
#     'ybr': '532.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '249.00',
#     'ytl': '917.00',
#     'xbr': '353.00',
#     'ybr': '964.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '443.00',
#     'ytl': '1331.00',
#     'xbr': '535.00',
#     'ybr': '1406.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '630.00',
#     'ytl': '1534.00',
#     'xbr': '696.00',
#     'ybr': '1602.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '248.00',
#     'ytl': '664.00',
#     'xbr': '325.00',
#     'ybr': '691.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '398.00',
#     'ytl': '1058.00',
#     'xbr': '495.00',
#     'ybr': '1109.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '0.00',
#     'ytl': '456.00',
#     'xbr': '44.00',
#     'ybr': '522.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '391.00',
#     'ytl': '669.00',
#     'xbr': '435.00',
#     'ybr': '696.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '943.00',
#     'ytl': '909.00',
#     'xbr': '1012.00',
#     'ybr': '962.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '322.00',
#     'ytl': '1023.00',
#     'xbr': '395.00',
#     'ybr': '1117.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '537.00',
#     'ytl': '679.00',
#     'xbr': '625.00',
#     'ybr': '736.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '253.00',
#     'ytl': '631.00',
#     'xbr': '323.00',
#     'ybr': '661.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '1.00',
#     'ytl': '651.00',
#     'xbr': '51.00',
#     'ybr': '682.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '143.00',
#     'ytl': '1157.00',
#     'xbr': '241.00',
#     'ybr': '1220.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '793.00',
#     'ytl': '911.00',
#     'xbr': '863.00',
#     'ybr': '964.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '507.00',
#     'ytl': '1551.00',
#     'xbr': '587.00',
#     'ybr': '1625.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '555.00',
#     'ytl': '1969.00',
#     'xbr': '653.00',
#     'ybr': '2000.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '757.00',
#     'ytl': '372.00',
#     'xbr': '820.00',
#     'ybr': '440.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '901.00',
#     'ytl': '427.00',
#     'xbr': '954.00',
#     'ybr': '551.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '834.00',
#     'ytl': '378.00',
#     'xbr': '900.00',
#     'ybr': '444.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '962.00',
#     'ytl': '1252.00',
#     'xbr': '1027.00',
#     'ybr': '1311.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '881.00',
#     'ytl': '1362.00',
#     'xbr': '950.00',
#     'ybr': '1474.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '693.00',
#     'ytl': '619.00',
#     'xbr': '764.00',
#     'ybr': '674.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '457.00',
#     'ytl': '1898.00',
#     'xbr': '539.00',
#     'ybr': '1989.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '598.00',
#     'ytl': '1109.00',
#     'xbr': '693.00',
#     'ybr': '1155.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '104.00',
#     'ytl': '1275.00',
#     'xbr': '190.00',
#     'ybr': '1319.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '361.00',
#     'ytl': '1914.00',
#     'xbr': '449.00',
#     'ybr': '1998.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '30.00',
#     'ytl': '802.00',
#     'xbr': '136.00',
#     'ybr': '855.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '243.00',
#     'ytl': '1023.00',
#     'xbr': '317.00',
#     'ybr': '1120.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '438.00',
#     'ytl': '1410.00',
#     'xbr': '530.00',
#     'ybr': '1491.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '761.00',
#     'ytl': '498.00',
#     'xbr': '821.00',
#     'ybr': '546.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '697.00',
#     'ytl': '1054.00',
#     'xbr': '791.00',
#     'ybr': '1107.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '197.00',
#     'ytl': '1271.00',
#     'xbr': '289.00',
#     'ybr': '1320.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '174.00',
#     'ytl': '698.00',
#     'xbr': '242.00',
#     'ybr': '720.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '621.00',
#     'ytl': '1261.00',
#     'xbr': '702.00',
#     'ybr': '1303.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '461.00',
#     'ytl': '1981.00',
#     'xbr': '537.00',
#     'ybr': '2000.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '337.00',
#     'ytl': '1755.00',
#     'xbr': '424.00',
#     'ybr': '1802.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '598.00',
#     'ytl': '1056.00',
#     'xbr': '693.00',
#     'ybr': '1106.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '498.00',
#     'ytl': '1111.00',
#     'xbr': '595.00',
#     'ybr': '1156.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '643.00',
#     'ytl': '859.00',
#     'xbr': '714.00',
#     'ybr': '907.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '357.00',
#     'ytl': '916.00',
#     'xbr': '457.00',
#     'ybr': '963.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '335.00',
#     'ytl': '1638.00',
#     'xbr': '427.00',
#     'ybr': '1709.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '941.00',
#     'ytl': '1112.00',
#     'xbr': '1009.00',
#     'ybr': '1202.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '613.00',
#     'ytl': '463.00',
#     'xbr': '688.00',
#     'ybr': '538.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '246.00',
#     'ytl': '1123.00',
#     'xbr': '319.00',
#     'ybr': '1218.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '546.00',
#     'ytl': '650.00',
#     'xbr': '628.00',
#     'ybr': '677.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '634.00',
#     'ytl': '676.00',
#     'xbr': '722.00',
#     'ybr': '714.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '616.00',
#     'ytl': '1856.00',
#     'xbr': '678.00',
#     'ybr': '1944.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '631.00',
#     'ytl': '1606.00',
#     'xbr': '697.00',
#     'ybr': '1688.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '778.00',
#     'ytl': '1880.00',
#     'xbr': '861.00',
#     'ybr': '2000.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '30.00',
#     'ytl': '859.00',
#     'xbr': '135.00',
#     'ybr': '905.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '834.00',
#     'ytl': '446.00',
#     'xbr': '897.00',
#     'ybr': '499.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '398.00',
#     'ytl': '697.00',
#     'xbr': '436.00',
#     'ybr': '720.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '954.00',
#     'ytl': '1345.00',
#     'xbr': '1012.00',
#     'ybr': '1464.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '128.00',
#     'ytl': '468.00',
#     'xbr': '199.00',
#     'ybr': '527.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '366.00',
#     'ytl': '1373.00',
#     'xbr': '433.00',
#     'ybr': '1487.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '1020.00',
#     'ytl': '849.00',
#     'xbr': '1088.00',
#     'ybr': '898.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '1.00',
#     'ytl': '686.00',
#     'xbr': '56.00',
#     'ybr': '713.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '758.00',
#     'ytl': '442.00',
#     'xbr': '820.00',
#     'ybr': '495.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '339.00',
#     'ytl': '697.00',
#     'xbr': '392.00',
#     'ybr': '734.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '249.00',
#     'ytl': '867.00',
#     'xbr': '353.00',
#     'ybr': '914.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '539.00',
#     'ytl': '1377.00',
#     'xbr': '621.00',
#     'ybr': '1422.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '0.00',
#     'ytl': '388.00',
#     'xbr': '48.00',
#     'ybr': '451.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '139.00',
#     'ytl': '917.00',
#     'xbr': '245.00',
#     'ybr': '964.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '1073.00',
#     'ytl': '902.00',
#     'xbr': '1125.00',
#     'ybr': '959.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '2.00',
#     'ytl': '1296.00',
#     'xbr': '96.00',
#     'ybr': '1385.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '498.00',
#     'ytl': '1057.00',
#     'xbr': '594.00',
#     'ybr': '1107.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '707.00',
#     'ytl': '412.00',
#     'xbr': '755.00',
#     'ybr': '477.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '243.00',
#     'ytl': '380.00',
#     'xbr': '327.00',
#     'ybr': '452.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '944.00',
#     'ytl': '857.00',
#     'xbr': '1012.00',
#     'ybr': '907.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '438.00',
#     'ytl': '639.00',
#     'xbr': '530.00',
#     'ybr': '677.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '567.00',
#     'ytl': '800.00',
#     'xbr': '639.00',
#     'ybr': '856.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '777.00',
#     'ytl': '1630.00',
#     'xbr': '862.00',
#     'ybr': '1673.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '696.00',
#     'ytl': '1109.00',
#     'xbr': '791.00',
#     'ybr': '1155.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '168.00',
#     'ytl': '1944.00',
#     'xbr': '260.00',
#     'ybr': '2000.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '869.00',
#     'ytl': '856.00',
#     'xbr': '941.00',
#     'ybr': '906.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '381.00',
#     'ytl': '629.00',
#     'xbr': '429.00',
#     'ybr': '657.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '698.00',
#     'ytl': '511.00',
#     'xbr': '756.00',
#     'ybr': '542.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '498.00',
#     'ytl': '1159.00',
#     'xbr': '594.00',
#     'ybr': '1212.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '774.00',
#     'ytl': '1585.00',
#     'xbr': '862.00',
#     'ybr': '1627.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '633.00',
#     'ytl': '714.00',
#     'xbr': '725.00',
#     'ybr': '751.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '462.00',
#     'ytl': '819.00',
#     'xbr': '563.00',
#     'ybr': '866.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '89.00',
#     'ytl': '1727.00',
#     'xbr': '144.00',
#     'ybr': '1814.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '782.00',
#     'ytl': '1720.00',
#     'xbr': '866.00',
#     'ybr': '1770.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '598.00',
#     'ytl': '1159.00',
#     'xbr': '693.00',
#     'ybr': '1212.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '895.00',
#     'ytl': '1817.00',
#     'xbr': '970.00',
#     'ybr': '1883.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '462.00',
#     'ytl': '870.00',
#     'xbr': '561.00',
#     'ybr': '913.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '536.00',
#     'ytl': '1425.00',
#     'xbr': '621.00',
#     'ybr': '1475.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '1012.00',
#     'ytl': '1323.00',
#     'xbr': '1052.00',
#     'ybr': '1436.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '534.00',
#     'ytl': '1734.00',
#     'xbr': '624.00',
#     'ybr': '1791.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '629.00',
#     'ytl': '1307.00',
#     'xbr': '707.00',
#     'ybr': '1351.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '852.00',
#     'ytl': '632.00',
#     'xbr': '984.00',
#     'ybr': '753.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '438.00',
#     'ytl': '1741.00',
#     'xbr': '525.00',
#     'ybr': '1788.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '870.00',
#     'ytl': '1019.00',
#     'xbr': '939.00',
#     'ybr': '1111.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '1088.00',
#     'ytl': '1022.00',
#     'xbr': '1123.00',
#     'ybr': '1105.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '441.00',
#     'ytl': '479.00',
#     'xbr': '519.00',
#     'ybr': '535.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '945.00',
#     'ytl': '804.00',
#     'xbr': '1016.00',
#     'ybr': '855.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '64.00',
#     'ytl': '707.00',
#     'xbr': '142.00',
#     'ybr': '743.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '462.00',
#     'ytl': '917.00',
#     'xbr': '561.00',
#     'ybr': '964.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '103.00',
#     'ytl': '1322.00',
#     'xbr': '181.00',
#     'ybr': '1364.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '30.00',
#     'ytl': '909.00',
#     'xbr': '134.00',
#     'ybr': '962.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '156.00',
#     'ytl': '1667.00',
#     'xbr': '240.00',
#     'ybr': '1811.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '643.00',
#     'ytl': '803.00',
#     'xbr': '716.00',
#     'ybr': '855.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '719.00',
#     'ytl': '911.00',
#     'xbr': '788.00',
#     'ybr': '964.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '572.00',
#     'ytl': '404.00',
#     'xbr': '648.00',
#     'ybr': '464.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '1.00',
#     'ytl': '1402.00',
#     'xbr': '72.00',
#     'ybr': '1502.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '246.00',
#     'ytl': '691.00',
#     'xbr': '323.00',
#     'ybr': '716.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '288.00',
#     'ytl': '1378.00',
#     'xbr': '362.00',
#     'ybr': '1497.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '1023.00',
#     'ytl': '428.00',
#     'xbr': '1084.00',
#     'ybr': '552.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '400.00',
#     'ytl': '721.00',
#     'xbr': '436.00',
#     'ybr': '746.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '1.00',
#     'ytl': '714.00',
#     'xbr': '56.00',
#     'ybr': '741.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '336.00',
#     'ytl': '1711.00',
#     'xbr': '425.00',
#     'ybr': '1752.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '755.00',
#     'ytl': '715.00',
#     'xbr': '845.00',
#     'ybr': '752.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '944.00',
#     'ytl': '1016.00',
#     'xbr': '1011.00',
#     'ybr': '1109.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '535.00',
#     'ytl': '1669.00',
#     'xbr': '623.00',
#     'ybr': '1766.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '748.00',
#     'ytl': '674.00',
#     'xbr': '838.00',
#     'ybr': '712.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '184.00',
#     'ytl': '1395.00',
#     'xbr': '279.00',
#     'ybr': '1443.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '173.00',
#     'ytl': '666.00',
#     'xbr': '241.00',
#     'ybr': '698.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '1016.00',
#     'ytl': '902.00',
#     'xbr': '1070.00',
#     'ybr': '959.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '780.00',
#     'ytl': '1677.00',
#     'xbr': '864.00',
#     'ybr': '1717.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '627.00',
#     'ytl': '1426.00',
#     'xbr': '721.00',
#     'ybr': '1476.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '186.00',
#     'ytl': '1334.00',
#     'xbr': '280.00',
#     'ybr': '1392.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '868.00',
#     'ytl': '909.00',
#     'xbr': '940.00',
#     'ybr': '963.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '1009.00',
#     'ytl': '672.00',
#     'xbr': '1086.00',
#     'ybr': '756.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '248.00',
#     'ytl': '816.00',
#     'xbr': '353.00',
#     'ybr': '865.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '1082.00',
#     'ytl': '1112.00',
#     'xbr': '1124.00',
#     'ybr': '1197.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '51.00',
#     'ytl': '495.00',
#     'xbr': '116.00',
#     'ybr': '524.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '53.00',
#     'ytl': '439.00',
#     'xbr': '107.00',
#     'ybr': '492.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '792.00',
#     'ytl': '856.00',
#     'xbr': '866.00',
#     'ybr': '908.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '704.00',
#     'ytl': '1672.00',
#     'xbr': '770.00',
#     'ybr': '1778.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '140.00',
#     'ytl': '869.00',
#     'xbr': '246.00',
#     'ybr': '914.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '452.00',
#     'ytl': '1263.00',
#     'xbr': '538.00',
#     'ybr': '1327.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '537.00',
#     'ytl': '715.00',
#     'xbr': '625.00',
#     'ybr': '750.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '1089.00',
#     'ytl': '672.00',
#     'xbr': '1125.00',
#     'ybr': '757.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '774.00',
#     'ytl': '1533.00',
#     'xbr': '864.00',
#     'ybr': '1581.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '399.00',
#     'ytl': '1162.00',
#     'xbr': '495.00',
#     'ybr': '1214.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '1086.00',
#     'ytl': '430.00',
#     'xbr': '1125.00',
#     'ybr': '553.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '947.00',
#     'ytl': '1598.00',
#     'xbr': '1039.00',
#     'ybr': '1748.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '103.00',
#     'ytl': '1367.00',
#     'xbr': '180.00',
#     'ybr': '1412.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '567.00',
#     'ytl': '912.00',
#     'xbr': '640.00',
#     'ybr': '965.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '357.00',
#     'ytl': '812.00',
#     'xbr': '456.00',
#     'ybr': '864.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '1012.00',
#     'ytl': '1111.00',
#     'xbr': '1080.00',
#     'ybr': '1200.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '523.00',
#     'ytl': '481.00',
#     'xbr': '598.00',
#     'ybr': '536.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '1015.00',
#     'ytl': '1015.00',
#     'xbr': '1082.00',
#     'ybr': '1107.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '698.00',
#     'ytl': '1158.00',
#     'xbr': '791.00',
#     'ybr': '1209.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '78.00',
#     'ytl': '1425.00',
#     'xbr': '178.00',
#     'ybr': '1503.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '437.00',
#     'ytl': '1675.00',
#     'xbr': '525.00',
#     'ybr': '1738.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '719.00',
#     'ytl': '856.00',
#     'xbr': '788.00',
#     'ybr': '908.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '246.00',
#     'ytl': '1662.00',
#     'xbr': '327.00',
#     'ybr': '1806.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '985.00',
#     'ytl': '1814.00',
#     'xbr': '1060.00',
#     'ybr': '1895.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '362.00',
#     'ytl': '468.00',
#     'xbr': '434.00',
#     'ybr': '533.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '686.00',
#     'ytl': '1884.00',
#     'xbr': '771.00',
#     'ybr': '1997.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '34.00',
#     'ytl': '1170.00',
#     'xbr': '138.00',
#     'ybr': '1219.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '138.00',
#     'ytl': '406.00',
#     'xbr': '214.00',
#     'ybr': '461.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '627.00',
#     'ytl': '1363.00',
#     'xbr': '721.00',
#     'ybr': '1423.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '205.00',
#     'ytl': '458.00',
#     'xbr': '278.00',
#     'ybr': '529.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '643.00',
#     'ytl': '911.00',
#     'xbr': '714.00',
#     'ybr': '964.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '1.00',
#     'ytl': '317.00',
#     'xbr': '58.00',
#     'ybr': '383.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '698.00',
#     'ytl': '479.00',
#     'xbr': '755.00',
#     'ybr': '509.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '141.00',
#     'ytl': '816.00',
#     'xbr': '246.00',
#     'ybr': '864.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '175.00',
#     'ytl': '720.00',
#     'xbr': '242.00',
#     'ybr': '745.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '541.00',
#     'ytl': '1317.00',
#     'xbr': '623.00',
#     'ybr': '1373.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '75.00',
#     'ytl': '1619.00',
#     'xbr': '147.00',
#     'ybr': '1722.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '567.00',
#     'ytl': '859.00',
#     'xbr': '639.00',
#     'ybr': '908.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '322.00',
#     'ytl': '1122.00',
#     'xbr': '396.00',
#     'ybr': '1216.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '834.00',
#     'ytl': '502.00',
#     'xbr': '896.00',
#     'ybr': '549.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '1050.00',
#     'ytl': '1603.00',
#     'xbr': '1125.00',
#     'ybr': '1759.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '34.00',
#     'ytl': '1115.00',
#     'xbr': '138.00',
#     'ybr': '1166.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '357.00',
#     'ytl': '866.00',
#     'xbr': '457.00',
#     'ybr': '913.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '438.00',
#     'ytl': '717.00',
#     'xbr': '530.00',
#     'ybr': '749.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '185.00',
#     'ytl': '1446.00',
#     'xbr': '279.00',
#     'ybr': '1499.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '957.00',
#     'ytl': '426.00',
#     'xbr': '1016.00',
#     'ybr': '551.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '798.00',
#     'ytl': '1020.00',
#     'xbr': '866.00',
#     'ybr': '1112.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '399.00',
#     'ytl': '1113.00',
#     'xbr': '495.00',
#     'ybr': '1159.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '247.00',
#     'ytl': '719.00',
#     'xbr': '321.00',
#     'ybr': '746.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '438.00',
#     'ytl': '679.00',
#     'xbr': '531.00',
#     'ybr': '713.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '868.00',
#     'ytl': '803.00',
#     'xbr': '941.00',
#     'ybr': '855.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '795.00',
#     'ytl': '1115.00',
#     'xbr': '864.00',
#     'ybr': '1207.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '265.00',
#     'ytl': '1938.00',
#     'xbr': '353.00',
#     'ybr': '2000.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '870.00',
#     'ytl': '1114.00',
#     'xbr': '938.00',
#     'ybr': '1205.00',
#     'z_order': '0'},
#    {'label': 'ignore',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '630.00',
#     'ytl': '1692.00',
#     'xbr': '697.00',
#     'ybr': '1783.00',
#     'z_order': '0'}],
#   'points': [{'label': 'Курганский МК Конина тушеная 325 гр.',
#     'occluded': '0',
#     'source': 'manual',
#     'points': '453.46,1092.31',
#     'z_order': '0'},
#    {'label': 'Курганский МК Говядина тушеная в/с 338 гр.',
#     'occluded': '0',
#     'source': 'manual',
#     'points': '1047.89,1060.66',
#     'z_order': '0'},
#    {'label': 'Perva Extra Ветчина из мяса курицы 180 гр.',
#     'occluded': '0',
#     'source': 'manual',
#     'points': '685.29,893.30',
#     'z_order': '0'},
#    {'label': 'other',
#     'occluded': '0',
#     'source': 'manual',
#     'points': '1054.80,717.75',
#     'z_order': '0'},
#    {'label': 'Perva Начинка для лаваша куриная 180 гр.',
#     'occluded': '0',
#     'source': 'manual',
#     'points': '910.33,828.72',
#     'z_order': '0'},
#    {'label': 'Perva Extra Ветчина из мяса курицы 180 гр.',
#     'occluded': '0',
#     'source': 'manual',
#     'points': '603.74,828.06',
#     'z_order': '0'},
#    {'label': 'Myaso в банке Оленина тушеная в/с 338 гр.',
#     'occluded': '0',
#     'source': 'manual',
#     'points': '281.89,1073.65',
#     'z_order': '0'},
#    {'label': 'Курганский МК Халяль Говядина "Курганская" 325 г.',
#     'occluded': '0',
#     'source': 'manual',
#     'points': '653.44,1079.69',
#     'z_order': '0'},
#    {'label': 'Курганский МК Халяль Говядина "Курганская" 325 г.',
#     'occluded': '0',
#     'source': 'manual',
#     'points': '631.54,1135.56',
#     'z_order': '0'},
#    {'label': 'Perva Extra Ветчина из мяса курицы 180 гр.',
#     'occluded': '0',
#     'source': 'manual',
#     'points': '613.53,882.42',
#     'z_order': '0'},
#    {'label': 'Perva Начинка для лаваша куриная 180 гр.',
#     'occluded': '0',
#     'source': 'manual',
#     'points': '983.33,828.72',
#     'z_order': '0'},
#    {'label': 'Курганский МК Говядина тушеная в/с 338 гр.',
#     'occluded': '0',
#     'source': 'manual',
#     'points': '969.23,1147.50',
#     'z_order': '0'},
#    {'label': 'Myaso в банке Оленина тушеная в/с 338 гр.',
#     'occluded': '0',
#     'source': 'manual',
#     'points': '365.16,1166.07',
#     'z_order': '0'},
#    {'label': 'Курганский МК Говядина "Курганская" 340 гр. Пригожино металл',
#     'occluded': '0',
#     'source': 'manual',
#     'points': '913.86,1059.40',
#     'z_order': '0'},
#    {'label': 'Perva Fitness Филе индейки в собственном соку 180 гр.',
#     'occluded': '0',
#     'source': 'manual',
#     'points': '757.66,885.84',
#     'z_order': '0'},
#    {'label': 'Perva Fitness Филе индейки в собственном соку 180 гр.',
#     'occluded': '0',
#     'source': 'manual',
#     'points': '826.49,887.66',
#     'z_order': '0'},
#    {'label': 'Курганский МК Конина тушеная 325 гр.',
#     'occluded': '0',
#     'source': 'manual',
#     'points': '547.80,1089.51',
#     'z_order': '0'},
#    {'label': 'Курганский МК Говядина "Курганская" 340 гр. Пригожино металл',
#     'occluded': '0',
#     'source': 'manual',
#     'points': '913.23,1153.79',
#     'z_order': '0'}]}}

# %%
from PIL import Image, ImageDraw
import os

def get_unique_filename(file_path):
    base, extension = os.path.splitext(file_path)
    counter = 1
    while os.path.exists(file_path):
        file_path = f"{base}_{counter}{extension}"
        counter += 1
    return file_path

def save_crop(img_name, bbox_orig, destination):
    image_path = img_name
    original_image = Image.open(image_path)
    cropped_image = original_image.crop(bbox_orig)
    cropped_image.save(destination)

# %%
for image_data in images_data:
    checked = 0
    for point_data in image_data['children']['points']:
        point_data_coord = list(map(int, map(float, point_data['points'].split(','))))
        for box_data in image_data['children']['box']:
            box_bbox = [int(float(box_data['xtl'])), int(float(box_data['ytl'])), 
                        int(float(box_data['xbr'])), int(float(box_data['ybr']))]
            if point_data['label'].lower() in brands and (box_bbox[0] < point_data_coord[0] < box_bbox[2] and 
                                                          box_bbox[1] < point_data_coord[1] < box_bbox[3]):
                box_data['label'] = point_data['label']
                box_data['x'] = point_data_coord[0]
                box_data['y'] = point_data_coord[1]
                destination = get_unique_filename(f'data/{folder_name}/cropped/' + 'cropped_' + image_data['attributes']['name'])
                save_crop(f'data/{folder_name}/images/' + image_data['attributes']['name'], box_bbox, destination)
                box_data['cropped_name'] = destination.split('/')[-1]
                checked = 1
    image_data['checked'] = checked

# %%
images_changed_data = [x for x in images_data if x['checked'] == 1]

# %%
len(images_changed_data)
# Out:
# 41

# %%
for image_data in images_changed_data:
    image_data['children']['box'] = [x for x in image_data['children']['box'] if x['label'] != 'ignore']
    try:
        del image_data['children']['points']
    except:
        pass

# %%
len(images_changed_data)
# Out:
# 41

# %%
images_changed_data
# Out:
# [{'tag': 'image',
#   'attributes': {'id': '0',
#    'name': '-3avTAO79w.jpg',
#    'width': '1125',
#    'height': '2000'},
#   'children': {'box': [{'label': 'Курганский МК Халяль Говядина "Курганская" 325 г.',
#      'occluded': '0',
#      'source': 'manual',
#      'xtl': '598.00',
#      'ytl': '1109.00',
#      'xbr': '693.00',
#      'ybr': '1155.00',
#      'z_order': '0',
#      'x': 631,
#      'y': 1135,
#      'cropped_name': 'cropped_-3avTAO79w_40.jpg'},
#     {'label': 'Myaso в банке Оленина тушеная в/с 338 гр.',
#      'occluded': '0',
#      'source': 'manual',
#      'xtl': '243.00',
#      'ytl': '1023.00',
#      'xbr': '317.00',
#      'ybr': '1120.00',
#      'z_order': '0',
#      'x': 281,
#      'y': 1073,
#      'cropped_name': 'cropped_-3avTAO79w_38.jpg'},
#     {'label': 'Курганский МК Халяль Говядина "Курганская" 325 г.',
#      'occluded': '0',
#      'source': 'manual',
#      'xtl': '598.00',
#      'ytl': '1056.00',
#      'xbr': '693.00',
#      'ybr': '1106.00',
#      'z_order': '0',
#      'x': 653,
#      'y': 1079,
#      'cropped_name': 'cropped_-3avTAO79w_39.jpg'},
#     {'label': 'Perva Extra Ветчина из мяса курицы 180 гр.',
#      'occluded': '0',
#      'source': 'manual',
#      'xtl': '643.00',
#      'ytl': '859.00',
#      'xbr': '714.00',
#      'ybr': '907.00',
#      'z_order': '0',
#      'x': 685,
#      'y': 893,
#      'cropped_name': 'cropped_-3avTAO79w_36.jpg'},
#     {'label': 'Perva Extra Ветчина из мяса курицы 180 гр.',
#      'occluded': '0',
#      'source': 'manual',
#      'xtl': '567.00',
#      'ytl': '800.00',
#      'xbr': '639.00',
#      'ybr': '856.00',
#      'z_order': '0',
#      'x': 603,
#      'y': 828,
#      'cropped_name': 'cropped_-3avTAO79w_37.jpg'},
#     {'label': 'Perva Extra Ветчина из мяса курицы 180 гр.',
#      'occluded': '0',
#      'source': 'manual',
#      'xtl': '567.00',
#      'ytl': '859.00',
#      'xbr': '639.00',
#      'ybr': '908.00',
#      'z_order': '0',
#      'x': 613,
#      'y': 882,
#      'cropped_name': 'cropped_-3avTAO79w_41.jpg'},
#     {'label': 'Myaso в банке Оленина тушеная в/с 338 гр.',
#      'occluded': '0',
#      'source': 'manual',
#      'xtl': '322.00',
#      'ytl': '1122.00',
#      'xbr': '396.00',
#      'ybr': '1216.00',
#      'z_order': '0',
#      'x': 365,
#      'y': 1166,
#      'cropped_name': 'cropped_-3avTAO79w_42.jpg'}]},
#   'checked': 1},
#  {'tag': 'image',
#   'attributes': {'id': '3',
#    'name': '-Swo2MsnRg.jpeg',
#    'width': '1864',
#    'height': '2984'},
#   'children': {'box': [{'label': 'Myaso в банке Оленина тушеная в/с 338 гр.',
#      'occluded': '0',
#      'source': 'manual',
#      'xtl': '73.00',
#      'ytl': '1219.00',
#      'xbr': '259.00',
#      'ybr': '1457.00',
#      'z_order': '0',
#      'x': 152,
#      'y': 1332,
#      'cropped_name': 'cropped_-Swo2MsnRg_32.jpeg'},
#     {'label': 'Курганский МК Халяль Говядина "Курганская" 325 г.',
#      'occluded': '0',
#      'source': 'manual',
#      'xtl': '257.00',
#      'ytl': '657.00',
#      'xbr': '479.00',
#      'ybr': '784.00',
#      'z_order': '0',
#      'x': 343,
#      'y': 735,
#      'cropped_name': 'cropped_-Swo2MsnRg_34.jpeg'},
#     {'label': 'Курганский МК Халяль Говядина "Курганская" 325 г.',
#      'occluded': '0',
#      'source': 'manual',
#      'xtl': '492.00',
#      'ytl': '771.00',
#      'xbr': '740.00',
#      'ybr': '891.00',
#      'z_order': '0',
#      'x': 640,
#      'y': 852,
#      'cropped_name': 'cropped_-Swo2MsnRg_33.jpeg'},
#     {'label': 'Курганский МК Халяль Говядина "Курганская" 325 г.',
#      'occluded': '0',
#      'source': 'manual',
#      'xtl': '484.00',
#      'ytl': '632.00',
#      'xbr': '734.00',
#      'ybr': '764.00',
#      'z_order': '0',
#      'x': 607,
#      'y': 715,
#      'cropped_name': 'cropped_-Swo2MsnRg_35.jpeg'}]},
#   'checked': 1},
#  {'tag': 'image',
#   'attributes': {'id': '5',
#    'name': '-_In80p42nZ1tA.jpg',
#    'width': '736',
#    'height': '1632'},
#   'children': {'box': [{'label': 'Myaso в банке Оленина тушеная в/с 338 гр.',
#      'occluded': '0',
#      'source': 'manual',
#      'xtl': '233.00',
#      'ytl': '417.00',
#      'xbr': '287.00',
#      'ybr': '492.00',
#      'z_order': '0',
#      'x': 259,
#      'y': 443,
#      'cropped_name': 'cropped_-_In80p42nZ1tA_21.jpg'},
#     {'label': 'Myaso в банке Оленина тушеная в/с 338 гр.',
#      'occluded': '0',
#      'source': 'manual',
#      'xtl': '345.00',
#      'ytl': '418.00',
#      'xbr': '393.00',
#      'ybr': '492.00',
#      'z_order': '0',
#      'x': 376,
#      'y': 457,
#      'cropped_name': 'cropped_-_In80p42nZ1tA_20.jpg'}]},
#   'checked': 1},
#  {'tag': 'image',
#   'attributes': {'id': '9',
#    'name': '0CuIqLoofjKcfQ.jpg',
#    'width': '1440',
#    'height': '1920'},
#   'children': {'box': [{'label': 'Курганский МК Халяль Говядина "Курганская" 325 г.',
#      'occluded': '0',
#      'source': 'manual',
#      'xtl': '798.00',
#      'ytl': '929.00',
#      'xbr': '861.00',
#      'ybr': '962.00',
#      'z_order': '0',
#      'x': 830,
#      'y': 948,
#      'cropped_name': 'cropped_0CuIqLoofjKcfQ_37.jpg'},
#     {'label': 'Курганский МК Халяль Говядина "Курганская" 325 г.',
#      'occluded': '0',
#      'source': 'manual',
#      'xtl': '865.00',
#      'ytl': '929.00',
#      'xbr': '931.00',
#      'ybr': '964.00',
#      'z_order': '0',
#      'x': 899,
#      'y': 947,
#      'cropped_name': 'cropped_0CuIqLoofjKcfQ_36.jpg'},
#     {'label': 'Курганский МК Халяль Говядина "Курганская" 325 г.',
#      'occluded': '0',
#      'source': 'manual',
#      'xtl': '863.00',
#      'ytl': '965.00',
#      'xbr': '931.00',
#      'ybr': '1000.00',
#      'z_order': '0',
#      'x': 900,
#      'y': 980,
#      'cropped_name': 'cropped_0CuIqLoofjKcfQ_34.jpg'},
#     {'label': 'Myaso в банке Оленина тушеная в/с 338 гр.',
#      'occluded': '0',
#      'source': 'manual',
#      'xtl': '747.00',
#      'ytl': '872.00',
#      'xbr': '796.00',
#      'ybr': '933.00',
#      'z_order': '0',
#      'x': 768,
#      'y': 903,
#      'cropped_name': 'cropped_0CuIqLoofjKcfQ_38.jpg'},
#     {'label': 'Курганский МК Халяль Говядина "Курганская" 325 г.',
#      'occluded': '0',
#      'source': 'manual',
#      'xtl': '798.00',
#      'ytl': '964.00',
#      'xbr': '861.00',
#      'ybr': '999.00',
#      'z_order': '0',
#      'x': 833,
#      'y': 978,
#      'cropped_name': 'cropped_0CuIqLoofjKcfQ_35.jpg'}]},
#   'checked': 1},
#  {'tag': 'image',
#   'attributes': {'id': '10',
#    'name': '0KcyA7RHwA.jpg',
#    'width': '1125',
#    'height': '2000'},
#   'children': {'box': [{'label': 'Myaso в банке Оленина тушеная в/с 338 гр.',
#      'occluded': '0',
#      'source': 'manual',
#      'xtl': '784.00',
#      'ytl': '813.00',
#      'xbr': '905.00',
#      'ybr': '970.00',
#      'z_order': '0',
#      'x': 849,
#      'y': 882,
#      'cropped_name': 'cropped_0KcyA7RHwA_12.jpg'}]},
#   'checked': 1},
#  {'tag': 'image',
#   'attributes': {'id': '13',
#    'name': '0UHfWxwwWw.jpg',
#    'width': '1152',
#    'height': '2048'},
#   'children': {'box': [{'label': 'Курганский МК Халяль Говядина "Курганская" 325 г.',
#      'occluded': '0',
#      'source': 'manual',
#      'xtl': '903.00',
#      'ytl': '750.00',
#      'xbr': '1092.00',
#      'ybr': '838.00',
#      'z_order': '0',
#      'x': 971,
#      'y': 818,
#      'cropped_name': 'cropped_0UHfWxwwWw_17.jpg'},
#     {'label': 'Курганский МК Халяль Говядина "Курганская" 325 г.',
#      'occluded': '0',
#      'source': 'manual',
#      'xtl': '726.00',
#      'ytl': '747.00',
#      'xbr': '898.00',
#      'ybr': '831.00',
#      'z_order': '0',
#      'x': 804,
#      'y': 795,
#      'cropped_name': 'cropped_0UHfWxwwWw_16.jpg'},
#     {'label': 'Perva Extra Ветчина из мяса курицы 180 гр.',
#      'occluded': '0',
#      'source': 'manual',
#      'xtl': '778.00',
#      'ytl': '1019.00',
#      'xbr': '899.00',
#      'ybr': '1102.00',
#      'z_order': '0',
#      'x': 841,
#      'y': 1072,
#      'cropped_name': 'cropped_0UHfWxwwWw_18.jpg'},
#     {'label': 'Perva Extra Ветчина из мяса курицы 180 гр.',
#      'occluded': '0',
#      'source': 'manual',
#      'xtl': '894.00',
#      'ytl': '1212.00',
#      'xbr': '1026.00',
#      'ybr': '1310.00',
#      'z_order': '0',
#      'x': 958,
#      'y': 1273,
#      'cropped_name': 'cropped_0UHfWxwwWw_19.jpg'}]},
#   'checked': 1},
#  {'tag': 'image',
#   'attributes': {'id': '25',
#    'name': '1JDdaF6CFg.jpg',
#    'width': '1125',
#    'height': '2000'},
#   'children': {'box': [{'label': 'Perva Extra Ветчина из мяса курицы 180 гр.',
#      'occluded': '0',
#      'source': 'manual',
#      'xtl': '520.00',
#      'ytl': '728.00',
#      'xbr': '596.00',
#      'ybr': '785.00',
#      'z_order': '0',
#      'x': 560,
#      'y': 746,
#      'cropped_name': 'cropped_1JDdaF6CFg_25.jpg'},
#     {'label': 'Perva Extra Ветчина из мяса курицы 180 гр.',
#      'occluded': '0',
#      'source': 'manual',
#      'xtl': '520.00',
#      'ytl': '671.00',
#      'xbr': '596.00',
#      'ybr': '725.00',
#      'z_order': '0',
#      'x': 566,
#      'y': 699,
#      'cropped_name': 'cropped_1JDdaF6CFg_24.jpg'}]},
#   'checked': 1},
#  {'tag': 'image',
#   'attributes': {'id': '31',
#    'name': '1ekvLPruHv4sEw.jpeg',
#    'width': '1280',
#    'height': '2050'},
#   'children': {'box': [{'label': 'Perva Extra Ветчина из мяса курицы 180 гр.',
#      'occluded': '0',
#      'source': 'manual',
#      'xtl': '609.00',
#      'ytl': '49.00',
#      'xbr': '740.00',
#      'ybr': '153.00',
#      'z_order': '0',
#      'x': 663,
#      'y': 119,
#      'cropped_name': 'cropped_1ekvLPruHv4sEw_13.jpeg'},
#     {'label': 'Perva Extra Ветчина из мяса курицы 180 гр.',
#      'occluded': '0',
#      'source': 'manual',
#      'xtl': '476.00',
#      'ytl': '162.00',
#      'xbr': '604.00',
#      'ybr': '265.00',
#      'z_order': '0',
#      'x': 543,
#      'y': 200,
#      'cropped_name': 'cropped_1ekvLPruHv4sEw_12.jpeg'},
#     {'label': 'Perva Extra Ветчина из мяса курицы 180 гр.',
#      'occluded': '0',
#      'source': 'manual',
#      'xtl': '610.00',
#      'ytl': '157.00',
#      'xbr': '740.00',
#      'ybr': '259.00',
#      'z_order': '0',
#      'x': 673,
#      'y': 212,
#      'cropped_name': 'cropped_1ekvLPruHv4sEw_15.jpeg'},
#     {'label': 'Perva Extra Ветчина из мяса курицы 180 гр.',
#      'occluded': '0',
#      'source': 'manual',
#      'xtl': '473.00',
#      'ytl': '47.00',
#      'xbr': '602.00',
#      'ybr': '157.00',
#      'z_order': '0',
#      'x': 539,
#      'y': 105,
#      'cropped_name': 'cropped_1ekvLPruHv4sEw_14.jpeg'}]},
#   'checked': 1},
#  {'tag': 'image',
#   'attributes': {'id': '32',
#    'name': '1hJNfO1CXSolmA.jpg',
#    'width': '1440',
#    'height': '1920'},
#   'children': {'box': [{'label': 'Perva Extra Ветчина из мяса курицы 180 гр.',
#      'occluded': '0',
#      'source': 'manual',
#      'xtl': '110.00',
#      'ytl': '790.00',
#      'xbr': '227.00',
#      'ybr': '871.00',
#      'z_order': '0',
#      'x': 163,
#      'y': 834,
#      'cropped_name': 'cropped_1hJNfO1CXSolmA_4.jpg'}]},
#   'checked': 1},
#  {'tag': 'image',
#   'attributes': {'id': '34',
#    'name': '1n19Xm8bBA.jpeg',
#    'width': '1864',
#    'height': '2984'},
#   'children': {'box': [{'label': 'Perva Extra Ветчина из мяса курицы 180 гр.',
#      'occluded': '0',
#      'source': 'manual',
#      'xtl': '264.00',
#      'ytl': '2262.00',
#      'xbr': '491.00',
#      'ybr': '2418.00',
#      'z_order': '0',
#      'x': 399,
#      'y': 2341,
#      'cropped_name': 'cropped_1n19Xm8bBA_8.jpeg'},
#     {'label': 'Perva Extra Ветчина из мяса курицы 180 гр.',
#      'occluded': '0',
#      'source': 'manual',
#      'xtl': '272.00',
#      'ytl': '2424.00',
#      'xbr': '498.00',
#      'ybr': '2602.00',
#      'z_order': '0',
#      'x': 405,
#      'y': 2520,
#      'cropped_name': 'cropped_1n19Xm8bBA_9.jpeg'},
#     {'label': 'Perva Extra Ветчина из мяса курицы 180 гр.',
#      'occluded': '0',
#      'source': 'manual',
#      'xtl': '507.00',
#      'ytl': '2411.00',
#      'xbr': '725.00',
#      'ybr': '2597.00',
#      'z_order': '0',
#      'x': 619,
#      'y': 2507,
#      'cropped_name': 'cropped_1n19Xm8bBA_10.jpeg'}]},
#   'checked': 1},
#  {'tag': 'image',
#   'attributes': {'id': '54',
#    'name': '3YUa9VS0Xw.jpeg',
#    'width': '1860',
#    'height': '2835'},
#   'children': {'box': [{'label': 'Perva Extra Ветчина из мяса курицы 180 гр.',
#      'occluded': '0',
#      'source': 'manual',
#      'xtl': '492.00',
#      'ytl': '718.00',
#      'xbr': '651.00',
#      'ybr': '838.00',
#      'z_order': '0',
#      'x': 576,
#      'y': 783,
#      'cropped_name': 'cropped_3YUa9VS0Xw_14.jpeg'},
#     {'label': 'Курганский МК Халяль Говядина "Курганская" 325 г.',
#      'occluded': '0',
#      'source': 'manual',
#      'xtl': '1308.00',
#      'ytl': '1762.00',
#      'xbr': '1538.00',
#      'ybr': '1884.00',
#      'z_order': '0',
#      'x': 1426,
#      'y': 1814,
#      'cropped_name': 'cropped_3YUa9VS0Xw_12.jpeg'},
#     {'label': 'Perva Extra Ветчина из мяса курицы 180 гр.',
#      'occluded': '0',
#      'source': 'manual',
#      'xtl': '495.00',
#      'ytl': '586.00',
#      'xbr': '651.00',
#      'ybr': '712.00',
#      'z_order': '0',
#      'x': 580,
#      'y': 656,
#      'cropped_name': 'cropped_3YUa9VS0Xw_15.jpeg'},
#     {'label': 'Курганский МК Халяль Говядина "Курганская" 325 г.',
#      'occluded': '0',
#      'source': 'manual',
#      'xtl': '1547.00',
#      'ytl': '1638.00',
#      'xbr': '1777.00',
#      'ybr': '1755.00',
#      'z_order': '0',
#      'x': 1675,
#      'y': 1698,
#      'cropped_name': 'cropped_3YUa9VS0Xw_13.jpeg'}]},
#   'checked': 1},
#  {'tag': 'image',
#   'attributes': {'id': '69',
#    'name': '4eg6gZAN1w.jpg',
#    'width': '1125',
#    'height': '2000'},
#   'children': {'box': [{'label': 'Perva Extra Ветчина из мяса курицы 180 гр.',
#      'occluded': '0',
#      'source': 'manual',
#      'xtl': '289.00',
#      'ytl': '671.00',
#      'xbr': '402.00',
#      'ybr': '757.00',
#      'z_order': '0',
#      'x': 354,
#      'y': 710,
#      'cropped_name': 'cropped_4eg6gZAN1w_29.jpg'},
#     {'label': 'Myaso в банке Оленина тушеная в/с 338 гр.',
#      'occluded': '0',
#      'source': 'manual',
#      'xtl': '634.00',
#      'ytl': '1261.00',
#      'xbr': '742.00',
#      'ybr': '1408.00',
#      'z_order': '0',
#      'x': 678,
#      'y': 1353,
#      'cropped_name': 'cropped_4eg6gZAN1w_31.jpg'},
#     {'label': 'Myaso в банке Оленина тушеная в/с 338 гр.',
#      'occluded': '0',
#      'source': 'manual',
#      'xtl': '523.00',
#      'ytl': '1259.00',
#      'xbr': '628.00',
#      'ybr': '1405.00',
#      'z_order': '0',
#      'x': 588,
#      'y': 1331,
#      'cropped_name': 'cropped_4eg6gZAN1w_28.jpg'},
#     {'label': 'Perva Extra Ветчина из мяса курицы 180 гр.',
#      'occluded': '0',
#      'source': 'manual',
#      'xtl': '172.00',
#      'ytl': '587.00',
#      'xbr': '284.00',
#      'ybr': '666.00',
#      'z_order': '0',
#      'x': 232,
#      'y': 621,
#      'cropped_name': 'cropped_4eg6gZAN1w_32.jpg'},
#     {'label': 'Курганский МК Халяль Говядина "Курганская" 325 г.',
#      'occluded': '0',
#      'source': 'manual',
#      'xtl': '387.00',
#      'ytl': '988.00',
#      'xbr': '531.00',
#      'ybr': '1059.00',
#      'z_order': '0',
#      'x': 458,
#      'y': 1026,
#      'cropped_name': 'cropped_4eg6gZAN1w_30.jpg'},
#     {'label': 'Perva Extra Ветчина из мяса курицы 180 гр.',
#      'occluded': '0',
#      'source': 'manual',
#      'xtl': '168.00',
#      'ytl': '491.00',
#      'xbr': '285.00',
#      'ybr': '584.00',
#      'z_order': '0',
#      'x': 210,
#      'y': 533,
#      'cropped_name': 'cropped_4eg6gZAN1w_33.jpg'}]},
#   'checked': 1},
#  {'tag': 'image',
#   'attributes': {'id': '71',
#    'name': '52p1VToVqA.jpg',
#    'width': '756',
#    'height': '1344'},
#   'children': {'box': [{'label': 'Perva Extra Ветчина из мяса курицы 180 гр.',
#      'occluded': '0',
#      'source': 'manual',
#      'xtl': '594.00',
#      'ytl': '552.00',
#      'xbr': '646.00',
#      'ybr': '591.00',
#      'z_order': '0',
#      'x': 624,
#      'y': 570,
#      'cropped_name': 'cropped_52p1VToVqA_17.jpg'},
#     {'label': 'Myaso в банке Оленина тушеная в/с 338 гр.',
#      'occluded': '0',
#      'source': 'manual',
#      'xtl': '329.00',
#      'ytl': '510.00',
#      'xbr': '377.00',
#      'ybr': '582.00',
#      'z_order': '0',
#      'x': 355,
#      'y': 544,
#      'cropped_name': 'cropped_52p1VToVqA_16.jpg'},
#     {'label': 'Курганский МК Халяль Говядина "Курганская" 325 г.',
#      'occluded': '0',
#      'source': 'manual',
#      'xtl': '374.00',
#      'ytl': '395.00',
#      'xbr': '443.00',
#      'ybr': '433.00',
#      'z_order': '0',
#      'x': 405,
#      'y': 411,
#      'cropped_name': 'cropped_52p1VToVqA_18.jpg'}]},
#   'checked': 1},
#  {'tag': 'image',
#   'attributes': {'id': '75',
#    'name': '5FEhHxUVfg.jpeg',
#    'width': '1864',
#    'height': '2984'},
#   'children': {'box': [{'label': 'Курганский МК Халяль Говядина "Курганская" 325 г.',
#      'occluded': '0',
#      'source': 'manual',
#      'xtl': '1596.00',
#      'ytl': '1036.00',
#      'xbr': '1860.00',
#      'ybr': '1174.00',
#      'z_order': '0',
#      'x': 1733,
#      'y': 1089,
#      'cropped_name': 'cropped_5FEhHxUVfg_14.jpeg'}]},
#   'checked': 1},
#  {'tag': 'image',
#   'attributes': {'id': '79',
#    'name': '5rouDe74wA.jpg',
#    'width': '1125',
#    'height': '2000'},
#   'children': {'box': [{'label': 'Myaso в банке Оленина тушеная в/с 338 гр.',
#      'occluded': '0',
#      'source': 'manual',
#      'xtl': '33.00',
#      'ytl': '1216.00',
#      'xbr': '180.00',
#      'ybr': '1414.00',
#      'z_order': '0',
#      'x': 115,
#      'y': 1304,
#      'cropped_name': 'cropped_5rouDe74wA_2.jpg'}]},
#   'checked': 1},
#  {'tag': 'image',
#   'attributes': {'id': '80',
#    'name': '5wIECnmjFg.jpg',
#    'width': '1440',
#    'height': '2560'},
#   'children': {'box': [{'label': 'Myaso в банке Оленина тушеная в/с 338 гр.',
#      'occluded': '0',
#      'source': 'manual',
#      'xtl': '939.00',
#      'ytl': '1343.00',
#      'xbr': '1039.00',
#      'ybr': '1475.00',
#      'z_order': '0',
#      'x': 987,
#      'y': 1401,
#      'cropped_name': 'cropped_5wIECnmjFg_13.jpg'},
#     {'label': 'Myaso в банке Оленина тушеная в/с 338 гр.',
#      'occluded': '0',
#      'source': 'manual',
#      'xtl': '1044.00',
#      'ytl': '1480.00',
#      'xbr': '1142.00',
#      'ybr': '1610.00',
#      'z_order': '0',
#      'x': 1092,
#      'y': 1532,
#      'cropped_name': 'cropped_5wIECnmjFg_12.jpg'}]},
#   'checked': 1},
#  {'tag': 'image',
#   'attributes': {'id': '84',
#    'name': '6DZDue-Vy2Ms0A.jpg',
#    'width': '1440',
#    'height': '1920'},
#   'children': {'box': [{'label': 'Myaso в банке Оленина тушеная в/с 338 гр.',
#      'occluded': '0',
#      'source': 'manual',
#      'xtl': '795.00',
#      'ytl': '863.00',
#      'xbr': '861.00',
#      'ybr': '953.00',
#      'z_order': '0',
#      'x': 834,
#      'y': 899,
#      'cropped_name': 'cropped_6DZDue-Vy2Ms0A_20.jpg'}]},
#   'checked': 1},
#  {'tag': 'image',
#   'attributes': {'id': '107',
#    'name': '8JUS4BoaSzb-4g.jpg',
#    'width': '1440',
#    'height': '1920'},
#   'children': {'box': [{'label': 'Myaso в банке Оленина тушеная в/с 338 гр.',
#      'occluded': '0',
#      'source': 'manual',
#      'xtl': '910.00',
#      'ytl': '1332.00',
#      'xbr': '985.00',
#      'ybr': '1418.00',
#      'z_order': '0',
#      'x': 940,
#      'y': 1389,
#      'cropped_name': 'cropped_8JUS4BoaSzb-4g_10.jpg'}]},
#   'checked': 1},
#  {'tag': 'image',
#   'attributes': {'id': '126',
#    'name': 'AWyWMgaNRSLpQQ.jpg',
#    'width': '1440',
#    'height': '1920'},
#   'children': {'box': [{'label': 'Myaso в банке Оленина тушеная в/с 338 гр.',
#      'occluded': '0',
#      'source': 'manual',
#      'xtl': '470.00',
#      'ytl': '767.00',
#      'xbr': '569.00',
#      'ybr': '895.00',
#      'z_order': '0',
#      'x': 526,
#      'y': 826,
#      'cropped_name': 'cropped_AWyWMgaNRSLpQQ_13.jpg'},
#     {'label': 'Myaso в банке Оленина тушеная в/с 338 гр.',
#      'occluded': '0',
#      'source': 'manual',
#      'xtl': '472.00',
#      'ytl': '646.00',
#      'xbr': '572.00',
#      'ybr': '764.00',
#      'z_order': '0',
#      'x': 528,
#      'y': 708,
#      'cropped_name': 'cropped_AWyWMgaNRSLpQQ_12.jpg'}]},
#   'checked': 1},
#  {'tag': 'image',
#   'attributes': {'id': '127',
#    'name': 'AsXRKU74wQ.jpeg',
#    'width': '1864',
#    'height': '2984'},
#   'children': {'box': [{'label': 'Perva Extra Ветчина из мяса курицы 180 гр.',
#      'occluded': '0',
#      'source': 'manual',
#      'xtl': '1392.00',
#      'ytl': '2397.00',
#      'xbr': '1600.00',
#      'ybr': '2546.00',
#      'z_order': '0',
#      'x': 1510,
#      'y': 2519,
#      'cropped_name': 'cropped_AsXRKU74wQ_8.jpeg'},
#     {'label': 'Курганский МК Халяль Говядина "Курганская" 325 г.',
#      'occluded': '0',
#      'source': 'manual',
#      'xtl': '1387.00',
#      'ytl': '1500.00',
#      'xbr': '1669.00',
#      'ybr': '1656.00',
#      'z_order': '0',
#      'x': 1501,
#      'y': 1580,
#      'cropped_name': 'cropped_AsXRKU74wQ_9.jpeg'}]},
#   'checked': 1},
#  {'tag': 'image',
#   'attributes': {'id': '128',
#    'name': 'B2sDviZsOo_8nQ.jpg',
#    'width': '1440',
#    'height': '1920'},
#   'children': {'box': [{'label': 'Курганский МК Халяль Говядина "Курганская" 325 г.',
#      'occluded': '0',
#      'source': 'manual',
#      'xtl': '344.00',
#      'ytl': '758.00',
#      'xbr': '458.00',
#      'ybr': '818.00',
#      'z_order': '0',
#      'x': 398,
#      'y': 795,
#      'cropped_name': 'cropped_B2sDviZsOo_8nQ_8.jpg'}]},
#   'checked': 1},
#  {'tag': 'image',
#   'attributes': {'id': '132',
#    'name': 'DEPK4looyg.jpg',
#    'width': '1125',
#    'height': '2000'},
#   'children': {'box': [{'label': 'Perva Extra Ветчина из мяса курицы 180 гр.',
#      'occluded': '0',
#      'source': 'manual',
#      'xtl': '700.00',
#      'ytl': '1289.00',
#      'xbr': '792.00',
#      'ybr': '1350.00',
#      'z_order': '0',
#      'x': 764,
#      'y': 1330,
#      'cropped_name': 'cropped_DEPK4looyg_23.jpg'},
#     {'label': 'Perva Extra Ветчина из мяса курицы 180 гр.',
#      'occluded': '0',
#      'source': 'manual',
#      'xtl': '701.00',
#      'ytl': '1216.00',
#      'xbr': '794.00',
#      'ybr': '1286.00',
#      'z_order': '0',
#      'x': 744,
#      'y': 1255,
#      'cropped_name': 'cropped_DEPK4looyg_22.jpg'},
#     {'label': 'Perva Extra Ветчина из мяса курицы 180 гр.',
#      'occluded': '0',
#      'source': 'manual',
#      'xtl': '607.00',
#      'ytl': '1285.00',
#      'xbr': '696.00',
#      'ybr': '1348.00',
#      'z_order': '0',
#      'x': 640,
#      'y': 1311,
#      'cropped_name': 'cropped_DEPK4looyg_26.jpg'},
#     {'label': 'Perva Extra Ветчина из мяса курицы 180 гр.',
#      'occluded': '0',
#      'source': 'manual',
#      'xtl': '607.00',
#      'ytl': '1205.00',
#      'xbr': '696.00',
#      'ybr': '1282.00',
#      'z_order': '0',
#      'x': 648,
#      'y': 1251,
#      'cropped_name': 'cropped_DEPK4looyg_24.jpg'},
#     {'label': 'Perva Extra Ветчина из мяса курицы 180 гр.',
#      'occluded': '0',
#      'source': 'manual',
#      'xtl': '700.00',
#      'ytl': '1353.00',
#      'xbr': '791.00',
#      'ybr': '1412.00',
#      'z_order': '0',
#      'x': 741,
#      'y': 1379,
#      'cropped_name': 'cropped_DEPK4looyg_27.jpg'},
#     {'label': 'Perva Extra Ветчина из мяса курицы 180 гр.',
#      'occluded': '0',
#      'source': 'manual',
#      'xtl': '699.00',
#      'ytl': '1417.00',
#      'xbr': '790.00',
#      'ybr': '1486.00',
#      'z_order': '0',
#      'x': 737,
#      'y': 1448,
#      'cropped_name': 'cropped_DEPK4looyg_20.jpg'},
#     {'label': 'Perva Extra Ветчина из мяса курицы 180 гр.',
#      'occluded': '0',
#      'source': 'manual',
#      'xtl': '604.00',
#      'ytl': '1414.00',
#      'xbr': '693.00',
#      'ybr': '1484.00',
#      'z_order': '0',
#      'x': 672,
#      'y': 1453,
#      'cropped_name': 'cropped_DEPK4looyg_25.jpg'},
#     {'label': 'Perva Extra Ветчина из мяса курицы 180 гр.',
#      'occluded': '0',
#      'source': 'manual',
#      'xtl': '606.00',
#      'ytl': '1350.00',
#      'xbr': '695.00',
#      'ybr': '1411.00',
#      'z_order': '0',
#      'x': 644,
#      'y': 1393,
#      'cropped_name': 'cropped_DEPK4looyg_21.jpg'}]},
#   'checked': 1},
#  {'tag': 'image',
#   'attributes': {'id': '145',
#    'name': 'KEude2HdGA.jpeg',
#    'width': '1864',
#    'height': '2984'},
#   'children': {'box': [{'label': 'Курганский МК Халяль Говядина "Курганская" 325 г.',
#      'occluded': '0',
#      'source': 'manual',
#      'xtl': '950.00',
#      'ytl': '940.00',
#      'xbr': '1214.00',
#      'ybr': '1083.00',
#      'z_order': '0',
#      'x': 1046,
#      'y': 1012,
#      'cropped_name': 'cropped_KEude2HdGA_7.jpeg'},
#     {'label': 'Курганский МК Халяль Говядина "Курганская" 325 г.',
#      'occluded': '0',
#      'source': 'manual',
#      'xtl': '413.00',
#      'ytl': '951.00',
#      'xbr': '676.00',
#      'ybr': '1093.00',
#      'z_order': '0',
#      'x': 497,
#      'y': 1049,
#      'cropped_name': 'cropped_KEude2HdGA_6.jpeg'}]},
#   'checked': 1},
#  {'tag': 'image',
#   'attributes': {'id': '146',
#    'name': 'KsR_2bDyeLvwYw.jpg',
#    'width': '1440',
#    'height': '1920'},
#   'children': {'box': [{'label': 'Myaso в банке Оленина тушеная в/с 338 гр.',
#      'occluded': '0',
#      'source': 'manual',
#      'xtl': '958.00',
#      'ytl': '642.00',
#      'xbr': '1058.00',
#      'ybr': '771.00',
#      'z_order': '0',
#      'x': 1013,
#      'y': 703,
#      'cropped_name': 'cropped_KsR_2bDyeLvwYw_13.jpg'},
#     {'label': 'Myaso в банке Оленина тушеная в/с 338 гр.',
#      'occluded': '0',
#      'source': 'manual',
#      'xtl': '957.00',
#      'ytl': '775.00',
#      'xbr': '1056.00',
#      'ybr': '898.00',
#      'z_order': '0',
#      'x': 998,
#      'y': 822,
#      'cropped_name': 'cropped_KsR_2bDyeLvwYw_12.jpg'}]},
#   'checked': 1},
#  {'tag': 'image',
#   'attributes': {'id': '148',
#    'name': 'LZFW9lT_tISXFA.jpg',
#    'width': '1440',
#    'height': '1920'},
#   'children': {'box': [{'label': 'Курганский МК Халяль Говядина "Курганская" 325 г.',
#      'occluded': '0',
#      'source': 'manual',
#      'xtl': '512.00',
#      'ytl': '1168.00',
#      'xbr': '598.00',
#      'ybr': '1214.00',
#      'z_order': '0',
#      'x': 564,
#      'y': 1198,
#      'cropped_name': 'cropped_LZFW9lT_tISXFA_2.jpg'}]},
#   'checked': 1},
#  {'tag': 'image',
#   'attributes': {'id': '152',
#    'name': 'MXvohPPExmln1g.jpg',
#    'width': '1440',
#    'height': '1920'},
#   'children': {'box': [{'label': 'Myaso в банке Оленина тушеная в/с 338 гр.',
#      'occluded': '0',
#      'source': 'manual',
#      'xtl': '1071.00',
#      'ytl': '733.00',
#      'xbr': '1184.00',
#      'ybr': '889.00',
#      'z_order': '0',
#      'x': 1133,
#      'y': 809,
#      'cropped_name': 'cropped_MXvohPPExmln1g_5.jpg'},
#     {'label': 'Myaso в банке Оленина тушеная в/с 338 гр.',
#      'occluded': '0',
#      'source': 'manual',
#      'xtl': '945.00',
#      'ytl': '735.00',
#      'xbr': '1066.00',
#      'ybr': '893.00',
#      'z_order': '0',
#      'x': 1007,
#      'y': 815,
#      'cropped_name': 'cropped_MXvohPPExmln1g_4.jpg'}]},
#   'checked': 1},
#  {'tag': 'image',
#   'attributes': {'id': '166',
#    'name': 'TGxz-u45-z0kCQ.jpg',
#    'width': '1440',
#    'height': '1920'},
#   'children': {'box': [{'label': 'Myaso в банке Оленина тушеная в/с 338 гр.',
#      'occluded': '0',
#      'source': 'manual',
#      'xtl': '788.00',
#      'ytl': '1336.00',
#      'xbr': '842.00',
#      'ybr': '1406.00',
#      'z_order': '0',
#      'x': 816,
#      'y': 1373,
#      'cropped_name': 'cropped_TGxz-u45-z0kCQ_2.jpg'}]},
#   'checked': 1},
#  {'tag': 'image',
#   'attributes': {'id': '176',
#    'name': 'ZZTJFlkR8Q.jpeg',
#    'width': '1864',
#    'height': '2984'},
#   'children': {'box': [{'label': 'Perva Extra Ветчина из мяса курицы 180 гр.',
#      'occluded': '0',
#      'source': 'manual',
#      'xtl': '861.00',
#      'ytl': '2714.00',
#      'xbr': '1071.00',
#      'ybr': '2858.00',
#      'z_order': '0',
#      'x': 975,
#      'y': 2814,
#      'cropped_name': 'cropped_ZZTJFlkR8Q_4.jpeg'}]},
#   'checked': 1},
#  {'tag': 'image',
#   'attributes': {'id': '199',
#    'name': 'cifUT4kY1Q.jpeg',
#    'width': '1864',
#    'height': '2984'},
#   'children': {'box': [{'label': 'Perva Extra Ветчина из мяса курицы 180 гр.',
#      'occluded': '0',
#      'source': 'manual',
#      'xtl': '1524.00',
#      'ytl': '205.00',
#      'xbr': '1743.00',
#      'ybr': '370.00',
#      'z_order': '0',
#      'x': 1615,
#      'y': 281,
#      'cropped_name': 'cropped_cifUT4kY1Q_38.jpeg'}]},
#   'checked': 1},
#  {'tag': 'image',
#   'attributes': {'id': '207',
#    'name': 'k7O-yBX6cjqqNQ.jpg',
#    'width': '1440',
#    'height': '1920'},
#   'children': {'box': [{'label': 'Myaso в банке Оленина тушеная в/с 338 гр.',
#      'occluded': '0',
#      'source': 'manual',
#      'xtl': '880.00',
#      'ytl': '854.00',
#      'xbr': '952.00',
#      'ybr': '945.00',
#      'z_order': '0',
#      'x': 921,
#      'y': 891,
#      'cropped_name': 'cropped_k7O-yBX6cjqqNQ_16.jpg'}]},
#   'checked': 1},
#  {'tag': 'image',
#   'attributes': {'id': '211',
#    'name': 'mrYa9dpL1SEelw.jpg',
#    'width': '1440',
#    'height': '1920'},
#   'children': {'box': [{'label': 'Perva Extra Ветчина из мяса курицы 180 гр.',
#      'occluded': '0',
#      'source': 'manual',
#      'xtl': '898.00',
#      'ytl': '736.00',
#      'xbr': '976.00',
#      'ybr': '795.00',
#      'z_order': '0',
#      'x': 927,
#      'y': 776,
#      'cropped_name': 'cropped_mrYa9dpL1SEelw_14.jpg'},
#     {'label': 'Myaso в банке Оленина тушеная в/с 338 гр.',
#      'occluded': '0',
#      'source': 'manual',
#      'xtl': '958.00',
#      'ytl': '1381.00',
#      'xbr': '1034.00',
#      'ybr': '1483.00',
#      'z_order': '0',
#      'x': 999,
#      'y': 1423,
#      'cropped_name': 'cropped_mrYa9dpL1SEelw_16.jpg'},
#     {'label': 'Perva Extra Ветчина из мяса курицы 180 гр.',
#      'occluded': '0',
#      'source': 'manual',
#      'xtl': '813.00',
#      'ytl': '730.00',
#      'xbr': '894.00',
#      'ybr': '794.00',
#      'z_order': '0',
#      'x': 848,
#      'y': 766,
#      'cropped_name': 'cropped_mrYa9dpL1SEelw_15.jpg'}]},
#   'checked': 1},
#  {'tag': 'image',
#   'attributes': {'id': '212',
#    'name': 'nH1cDfOCA-nPqw.jpg',
#    'width': '1440',
#    'height': '1920'},
#   'children': {'box': [{'label': 'Myaso в банке Оленина тушеная в/с 338 гр.',
#      'occluded': '0',
#      'source': 'manual',
#      'xtl': '765.00',
#      'ytl': '707.00',
#      'xbr': '870.00',
#      'ybr': '845.00',
#      'z_order': '0',
#      'x': 820,
#      'y': 771,
#      'cropped_name': 'cropped_nH1cDfOCA-nPqw_2.jpg'}]},
#   'checked': 1},
#  {'tag': 'image',
#   'attributes': {'id': '213',
#    'name': 'o1iiJZbauw.jpg',
#    'width': '1125',
#    'height': '2000'},
#   'children': {'box': [{'label': 'Курганский МК Халяль Говядина "Курганская" 325 г.',
#      'occluded': '0',
#      'source': 'manual',
#      'xtl': '262.00',
#      'ytl': '893.00',
#      'xbr': '346.00',
#      'ybr': '935.00',
#      'z_order': '0',
#      'x': 304,
#      'y': 914,
#      'cropped_name': 'cropped_o1iiJZbauw_9.jpg'},
#     {'label': 'Курганский МК Халяль Говядина "Курганская" 325 г.',
#      'occluded': '0',
#      'source': 'manual',
#      'xtl': '350.00',
#      'ytl': '934.00',
#      'xbr': '427.00',
#      'ybr': '980.00',
#      'z_order': '0',
#      'x': 390,
#      'y': 963,
#      'cropped_name': 'cropped_o1iiJZbauw_8.jpg'}]},
#   'checked': 1},
#  {'tag': 'image',
#   'attributes': {'id': '215',
#    'name': 'p3X-JTMb-Q.jpeg',
#    'width': '1864',
#    'height': '2984'},
#   'children': {'box': [{'label': 'Perva Extra Ветчина из мяса курицы 180 гр.',
#      'occluded': '0',
#      'source': 'manual',
#      'xtl': '606.00',
#      'ytl': '393.00',
#      'xbr': '794.00',
#      'ybr': '532.00',
#      'z_order': '0',
#      'x': 716,
#      'y': 453,
#      'cropped_name': 'cropped_p3X-JTMb-Q_5.jpeg'},
#     {'label': 'Perva Extra Ветчина из мяса курицы 180 гр.',
#      'occluded': '0',
#      'source': 'manual',
#      'xtl': '604.00',
#      'ytl': '243.00',
#      'xbr': '797.00',
#      'ybr': '386.00',
#      'z_order': '0',
#      'x': 751,
#      'y': 319,
#      'cropped_name': 'cropped_p3X-JTMb-Q_4.jpeg'}]},
#   'checked': 1},
#  {'tag': 'image',
#   'attributes': {'id': '217',
#    'name': 'ph4XMMaWjvMCAw.jpg',
#    'width': '1440',
#    'height': '1920'},
#   'children': {'box': [{'label': 'Курганский МК Халяль Говядина "Курганская" 325 г.',
#      'occluded': '0',
#      'source': 'manual',
#      'xtl': '960.00',
#      'ytl': '201.00',
#      'xbr': '1102.00',
#      'ybr': '288.00',
#      'z_order': '0',
#      'x': 1003,
#      'y': 238,
#      'cropped_name': 'cropped_ph4XMMaWjvMCAw_6.jpg'}]},
#   'checked': 1},
#  {'tag': 'image',
#   'attributes': {'id': '223',
#    'name': 'r9Qo_YVNUw.jpg',
#    'width': '1125',
#    'height': '2000'},
#   'children': {'box': [{'label': 'Курганский МК Халяль Говядина "Курганская" 325 г.',
#      'occluded': '0',
#      'source': 'manual',
#      'xtl': '868.00',
#      'ytl': '1215.00',
#      'xbr': '1012.00',
#      'ybr': '1290.00',
#      'z_order': '0',
#      'x': 940,
#      'y': 1246,
#      'cropped_name': 'cropped_r9Qo_YVNUw_29.jpg'},
#     {'label': 'Курганский МК Халяль Говядина "Курганская" 325 г.',
#      'occluded': '0',
#      'source': 'manual',
#      'xtl': '723.00',
#      'ytl': '1214.00',
#      'xbr': '855.00',
#      'ybr': '1289.00',
#      'z_order': '0',
#      'x': 797,
#      'y': 1257,
#      'cropped_name': 'cropped_r9Qo_YVNUw_30.jpg'},
#     {'label': 'Курганский МК Халяль Говядина "Курганская" 325 г.',
#      'occluded': '0',
#      'source': 'manual',
#      'xtl': '868.00',
#      'ytl': '1114.00',
#      'xbr': '1016.00',
#      'ybr': '1209.00',
#      'z_order': '0',
#      'x': 928,
#      'y': 1185,
#      'cropped_name': 'cropped_r9Qo_YVNUw_31.jpg'},
#     {'label': 'Курганский МК Халяль Говядина "Курганская" 325 г.',
#      'occluded': '0',
#      'source': 'manual',
#      'xtl': '721.00',
#      'ytl': '1113.00',
#      'xbr': '861.00',
#      'ybr': '1207.00',
#      'z_order': '0',
#      'x': 781,
#      'y': 1196,
#      'cropped_name': 'cropped_r9Qo_YVNUw_28.jpg'}]},
#   'checked': 1},
#  {'tag': 'image',
#   'attributes': {'id': '225',
#    'name': 'rqteDbbNJA.jpg',
#    'width': '1440',
#    'height': '2560'},
#   'children': {'box': [{'label': 'Myaso в банке Оленина тушеная в/с 338 гр.',
#      'occluded': '0',
#      'source': 'manual',
#      'xtl': '718.00',
#      'ytl': '1651.00',
#      'xbr': '784.00',
#      'ybr': '1737.00',
#      'z_order': '0',
#      'x': 745,
#      'y': 1698,
#      'cropped_name': 'cropped_rqteDbbNJA_16.jpg'},
#     {'label': 'Myaso в банке Оленина тушеная в/с 338 гр.',
#      'occluded': '0',
#      'source': 'manual',
#      'xtl': '789.00',
#      'ytl': '1651.00',
#      'xbr': '855.00',
#      'ybr': '1739.00',
#      'z_order': '0',
#      'x': 816,
#      'y': 1711,
#      'cropped_name': 'cropped_rqteDbbNJA_14.jpg'},
#     {'label': 'Myaso в банке Оленина тушеная в/с 338 гр.',
#      'occluded': '0',
#      'source': 'manual',
#      'xtl': '788.00',
#      'ytl': '1743.00',
#      'xbr': '854.00',
#      'ybr': '1827.00',
#      'z_order': '0',
#      'x': 823,
#      'y': 1775,
#      'cropped_name': 'cropped_rqteDbbNJA_15.jpg'},
#     {'label': 'Myaso в банке Оленина тушеная в/с 338 гр.',
#      'occluded': '0',
#      'source': 'manual',
#      'xtl': '717.00',
#      'ytl': '1740.00',
#      'xbr': '784.00',
#      'ybr': '1826.00',
#      'z_order': '0',
#      'x': 749,
#      'y': 1766,
#      'cropped_name': 'cropped_rqteDbbNJA_17.jpg'}]},
#   'checked': 1},
#  {'tag': 'image',
#   'attributes': {'id': '226',
#    'name': 'sNVLCGFmOA.jpeg',
#    'width': '1864',
#    'height': '2984'},
#   'children': {'box': [{'label': 'Курганский МК Халяль Говядина "Курганская" 325 г.',
#      'occluded': '0',
#      'source': 'manual',
#      'xtl': '1205.00',
#      'ytl': '717.00',
#      'xbr': '1480.00',
#      'ybr': '857.00',
#      'z_order': '0',
#      'x': 1343,
#      'y': 802,
#      'cropped_name': 'cropped_sNVLCGFmOA_20.jpeg'},
#     {'label': 'Курганский МК Халяль Говядина "Курганская" 325 г.',
#      'occluded': '0',
#      'source': 'manual',
#      'xtl': '1486.00',
#      'ytl': '711.00',
#      'xbr': '1754.00',
#      'ybr': '854.00',
#      'z_order': '0',
#      'x': 1625,
#      'y': 820,
#      'cropped_name': 'cropped_sNVLCGFmOA_21.jpeg'}]},
#   'checked': 1},
#  {'tag': 'image',
#   'attributes': {'id': '232',
#    'name': 'w-EDWqxpaF0Z4g.jpg',
#    'width': '1440',
#    'height': '1920'},
#   'children': {'box': [{'label': 'Курганский МК Халяль Говядина "Курганская" 325 г.',
#      'occluded': '0',
#      'source': 'manual',
#      'xtl': '505.00',
#      'ytl': '585.00',
#      'xbr': '626.00',
#      'ybr': '649.00',
#      'z_order': '0',
#      'x': 561,
#      'y': 615,
#      'cropped_name': 'cropped_w-EDWqxpaF0Z4g_12.jpg'},
#     {'label': 'Курганский МК Халяль Говядина "Курганская" 325 г.',
#      'occluded': '0',
#      'source': 'manual',
#      'xtl': '506.00',
#      'ytl': '521.00',
#      'xbr': '626.00',
#      'ybr': '581.00',
#      'z_order': '0',
#      'x': 551,
#      'y': 564,
#      'cropped_name': 'cropped_w-EDWqxpaF0Z4g_14.jpg'},
#     {'label': 'Курганский МК Халяль Говядина "Курганская" 325 г.',
#      'occluded': '0',
#      'source': 'manual',
#      'xtl': '505.00',
#      'ytl': '452.00',
#      'xbr': '628.00',
#      'ybr': '519.00',
#      'z_order': '0',
#      'x': 561,
#      'y': 494,
#      'cropped_name': 'cropped_w-EDWqxpaF0Z4g_13.jpg'}]},
#   'checked': 1},
#  {'tag': 'image',
#   'attributes': {'id': '238',
#    'name': 'zRwVxYoVqQ.jpg',
#    'width': '1125',
#    'height': '2000'},
#   'children': {'box': [{'label': 'Курганский МК Халяль Говядина "Курганская" 325 г.',
#      'occluded': '0',
#      'source': 'manual',
#      'xtl': '295.00',
#      'ytl': '500.00',
#      'xbr': '443.00',
#      'ybr': '571.00',
#      'z_order': '0',
#      'x': 358,
#      'y': 527,
#      'cropped_name': 'cropped_zRwVxYoVqQ_14.jpg'},
#     {'label': 'Курганский МК Халяль Говядина "Курганская" 325 г.',
#      'occluded': '0',
#      'source': 'manual',
#      'xtl': '296.00',
#      'ytl': '574.00',
#      'xbr': '443.00',
#      'ybr': '651.00',
#      'z_order': '0',
#      'x': 378,
#      'y': 613,
#      'cropped_name': 'cropped_zRwVxYoVqQ_15.jpg'}]},
#   'checked': 1},
#  {'tag': 'image',
#   'attributes': {'id': '239',
#    'name': 'zTlU9hQbOg.jpg',
#    'width': '1125',
#    'height': '2000'},
#   'children': {'box': [{'label': 'Курганский МК Халяль Говядина "Курганская" 325 г.',
#      'occluded': '0',
#      'source': 'manual',
#      'xtl': '475.00',
#      'ytl': '943.00',
#      'xbr': '557.00',
#      'ybr': '988.00',
#      'z_order': '0',
#      'x': 504,
#      'y': 962,
#      'cropped_name': 'cropped_zTlU9hQbOg_12.jpg'},
#     {'label': 'Курганский МК Халяль Говядина "Курганская" 325 г.',
#      'occluded': '0',
#      'source': 'manual',
#      'xtl': '564.00',
#      'ytl': '852.00',
#      'xbr': '649.00',
#      'ybr': '898.00',
#      'z_order': '0',
#      'x': 601,
#      'y': 881,
#      'cropped_name': 'cropped_zTlU9hQbOg_11.jpg'},
#     {'label': 'Курганский МК Халяль Говядина "Курганская" 325 г.',
#      'occluded': '0',
#      'source': 'manual',
#      'xtl': '476.00',
#      'ytl': '850.00',
#      'xbr': '560.00',
#      'ybr': '895.00',
#      'z_order': '0',
#      'x': 518,
#      'y': 878,
#      'cropped_name': 'cropped_zTlU9hQbOg_10.jpg'}]},
#   'checked': 1}]

# %%
import openpyxl
from openpyxl.drawing.image import Image
from openpyxl.utils import get_column_letter
from copy import deepcopy
from PIL import Image as PILImage

def pixels_to_width_units(pixels):
    return pixels / 7

def get_image_size_with_aspect_ratio(image_path, max_width):
    with PILImage.open(image_path) as img:
        original_width, original_height = img.size
        if original_width > max_width:
            scaling_factor = max_width / original_width
            new_width = max_width
            new_height = original_height * scaling_factor
            return new_width, new_height
        else:
            return original_width, original_height

wb = openpyxl.Workbook()
ws = wb.active

result = []
max_points = 0
copied_data = deepcopy(images_changed_data)

for image_data in copied_data:
    label_groups = {}
    for changed_point in image_data['children']['box']:
        if changed_point['label'] != 'ignore':
            label = changed_point['label']
            if label not in label_groups:
                label_groups[label] = []
            label_groups[label].append(changed_point)

    for label, points in label_groups.items():
        image_file_paths = []
        for point in points:
            local_file_path = f"data/{folder_name}/cropped/{point['cropped_name']}"
            image_file_paths.append(local_file_path)

        column = [label, None, None, image_data['attributes']['id'], image_data['attributes']['name'], len(points)] + image_file_paths

        if len(points) > max_points:
            max_points = len(points)

        result.append(column)

result.sort(key=lambda x: x[0])

headers = ['Название', 'фото эталон', 'task id', 'id фото в task', 'название фото', 'количество точек на фото'] + [f'фото{x}' for x in range(1, max_points + 1)]
ws.append(headers)

max_image_widths = [0] * max_points

for row, data in enumerate(result, start=2):
    max_height_in_row = 0
    for col, cell_value in enumerate(data, start=1):
        if isinstance(cell_value, str) and cell_value.startswith(f"data/{folder_name}/cropped/"):
            img_width, img_height = get_image_size_with_aspect_ratio(cell_value, 200) 
            img = Image(cell_value)
            img.width, img.height = img_width, img_height
            max_height_in_row = max(max_height_in_row, img.height)
            ws.add_image(img, get_column_letter(col) + str(row))

            image_col_index = col - 6
            if 0 <= image_col_index < len(max_image_widths):
                max_image_widths[image_col_index] = max(max_image_widths[image_col_index], img_width)
        else:
            ws.cell(row=row, column=col, value=cell_value)

    if max_height_in_row > 0:
        ws.row_dimensions[row].height = max_height_in_row * 0.75

for i, max_width in enumerate(max_image_widths, start=6):
    if max_width > 0:
        ws.column_dimensions[get_column_letter(i)].width = pixels_to_width_units(max_width)

ws.column_dimensions['A'].width = 40
ws.column_dimensions['E'].width = 20

wb.save(f'data/{folder_name}/output.xlsx')

# %% [markdown]
# # If label isn't necessary (cover all cases)

# %%
import xml.etree.ElementTree as ET

folder_name = '894_annotations'
file_path = f'data/{folder_name}/annotations.xml'

tree = ET.parse(file_path)
root = tree.getroot()

images_data = []
points, bboxes = [], []
for child in root:
    if child.tag == 'image':
        box = [subchild.attrib for subchild in child if subchild.tag == 'box']
        point = [subchild.attrib for subchild in child if subchild.tag == 'points']
        element_info = {
            'tag': child.tag,
            'attributes': child.attrib,
            'children': {'box': box, 'points': point}
        }
        images_data.append(element_info)

# %%
len(images_data)
# Out:
# 175

# %%
images_data[0]
# Out:
# {'tag': 'image',
#  'attributes': {'id': '0',
#   'name': '3Q2D_zCyxmo.jpg',
#   'width': '1800',
#   'height': '3200'},
#  'children': {'box': [{'label': 'Venetto',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '1315.15',
#     'ytl': '1590.12',
#     'xbr': '1396.94',
#     'ybr': '1665.18',
#     'z_order': '0'},
#    {'label': 'MONARCH',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '953.47',
#     'ytl': '650.55',
#     'xbr': '1062.91',
#     'ybr': '700.63',
#     'z_order': '0'},
#    {'label': 'Nescafe',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '1169.75',
#     'ytl': '1183.87',
#     'xbr': '1254.09',
#     'ybr': '1211.12',
#     'z_order': '0'},
#    {'label': 'Migel',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '1059.70',
#     'ytl': '2825.13',
#     'xbr': '1238.74',
#     'ybr': '2886.95',
#     'z_order': '0'},
#    {'label': 'MACCOFFEE',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '1583.36',
#     'ytl': '2846.30',
#     'xbr': '1776.30',
#     'ybr': '2909.40',
#     'z_order': '0'},
#    {'label': 'Nescafe',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '936.81',
#     'ytl': '1159.19',
#     'xbr': '1010.45',
#     'ybr': '1186.43',
#     'z_order': '0'},
#    {'label': 'Jacobs',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '485.36',
#     'ytl': '1932.91',
#     'xbr': '617.05',
#     'ybr': '1992.27',
#     'z_order': '0'},
#    {'label': 'Nescafe',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '1350.52',
#     'ytl': '2436.03',
#     'xbr': '1493.29',
#     'ybr': '2497.26',
#     'z_order': '0'},
#    {'label': 'Жокей',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '326.19',
#     'ytl': '1541.21',
#     'xbr': '407.44',
#     'ybr': '1613.51',
#     'z_order': '0'},
#    {'label': 'Venetto',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '1375.26',
#     'ytl': '1851.52',
#     'xbr': '1498.20',
#     'ybr': '1977.60',
#     'z_order': '0'},
#    {'label': 'MONARCH',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '429.45',
#     'ytl': '608.06',
#     'xbr': '538.88',
#     'ybr': '658.14',
#     'z_order': '0'},
#    {'label': 'Nescafe',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '305.79',
#     'ytl': '2487.99',
#     'xbr': '413.13',
#     'ybr': '2523.42',
#     'z_order': '0'},
#    {'label': 'Жокей',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '568.48',
#     'ytl': '1549.82',
#     'xbr': '649.73',
#     'ybr': '1622.13',
#     'z_order': '0'},
#    {'label': 'MONARCH',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '1373.51',
#     'ytl': '642.35',
#     'xbr': '1491.15',
#     'ybr': '705.85',
#     'z_order': '0'},
#    {'label': 'Migel',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '1406.19',
#     'ytl': '2883.09',
#     'xbr': '1558.18',
#     'ybr': '2977.12',
#     'z_order': '0'},
#    {'label': 'Nescafe',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '706.55',
#     'ytl': '1149.00',
#     'xbr': '780.20',
#     'ybr': '1176.24',
#     'z_order': '0'},
#    {'label': 'MONARCH',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '1084.66',
#     'ytl': '665.45',
#     'xbr': '1194.10',
#     'ybr': '715.53',
#     'z_order': '0'},
#    {'label': 'MONARCH',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '1622.85',
#     'ytl': '685.58',
#     'xbr': '1715.88',
#     'ybr': '737.15',
#     'z_order': '0'},
#    {'label': 'Venetto',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '1016.99',
#     'ytl': '1580.80',
#     'xbr': '1098.78',
#     'ybr': '1655.86',
#     'z_order': '0'},
#    {'label': 'Nescafe',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '170.00',
#     'ytl': '1187.40',
#     'xbr': '229.90',
#     'ybr': '1207.75',
#     'z_order': '0'},
#    {'label': 'Migel',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '1187.22',
#     'ytl': '2898.55',
#     'xbr': '1361.11',
#     'ybr': '2993.86',
#     'z_order': '0'},
#    {'label': 'MONARCH',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '562.13',
#     'ytl': '618.49',
#     'xbr': '671.57',
#     'ybr': '668.57',
#     'z_order': '0'},
#    {'label': 'MONARCH',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '4.53',
#     'ytl': '570.44',
#     'xbr': '113.97',
#     'ybr': '620.52',
#     'z_order': '0'},
#    {'label': 'MONARCH',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '143.21',
#     'ytl': '580.48',
#     'xbr': '252.64',
#     'ybr': '630.56',
#     'z_order': '0'},
#    {'label': 'Venetto',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '869.98',
#     'ytl': '1580.28',
#     'xbr': '951.77',
#     'ybr': '1655.34',
#     'z_order': '0'},
#    {'label': 'Venetto',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '1585.46',
#     'ytl': '1852.84',
#     'xbr': '1735.20',
#     'ybr': '1957.50',
#     'z_order': '0'},
#    {'label': 'Nescafe',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '823.02',
#     'ytl': '1155.96',
#     'xbr': '896.67',
#     'ybr': '1183.21',
#     'z_order': '0'},
#    {'label': 'МОСКОВСКАЯ КОФЕЙНЯ НА ПАЯХ',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '1173.52',
#     'ytl': '105.82',
#     'xbr': '1248.66',
#     'ybr': '158.41',
#     'z_order': '0'},
#    {'label': 'MONARCH',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '675.85',
#     'ytl': '1848.51',
#     'xbr': '876.80',
#     'ybr': '1934.80',
#     'z_order': '0'},
#    {'label': 'MONARCH',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '1509.17',
#     'ytl': '669.93',
#     'xbr': '1602.20',
#     'ybr': '721.50',
#     'z_order': '0'},
#    {'label': 'Venetto',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '1612.28',
#     'ytl': '1601.50',
#     'xbr': '1694.07',
#     'ybr': '1676.56',
#     'z_order': '0'},
#    {'label': 'Nescafe',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '673.21',
#     'ytl': '2429.60',
#     'xbr': '839.60',
#     'ybr': '2489.70',
#     'z_order': '0'},
#    {'label': 'Jardin',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '576.16',
#     'ytl': '57.58',
#     'xbr': '640.56',
#     'ybr': '100.09',
#     'z_order': '0'},
#    {'label': 'Nescafe',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '1055.95',
#     'ytl': '1139.87',
#     'xbr': '1140.30',
#     'ybr': '1167.11',
#     'z_order': '0'},
#    {'label': 'Nescafe',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '1676.39',
#     'ytl': '1167.77',
#     'xbr': '1760.73',
#     'ybr': '1195.02',
#     'z_order': '0'},
#    {'label': 'Jacobs',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '237.68',
#     'ytl': '1945.97',
#     'xbr': '369.38',
#     'ybr': '2005.33',
#     'z_order': '0'},
#    {'label': 'Migel',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '1004.31',
#     'ytl': '2970.68',
#     'xbr': '1165.32',
#     'ybr': '3058.27',
#     'z_order': '0'},
#    {'label': 'Nescafe',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '1479.94',
#     'ytl': '1217.15',
#     'xbr': '1553.59',
#     'ybr': '1244.39',
#     'z_order': '0'},
#    {'label': 'Nescafe',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '1104.71',
#     'ytl': '2409.20',
#     'xbr': '1231.40',
#     'ybr': '2453.30',
#     'z_order': '0'},
#    {'label': 'Venetto',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '1175.90',
#     'ytl': '1585.46',
#     'xbr': '1257.69',
#     'ybr': '1660.52',
#     'z_order': '0'},
#    {'label': 'Venetto',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '720.49',
#     'ytl': '1575.64',
#     'xbr': '802.28',
#     'ybr': '1650.70',
#     'z_order': '0'},
#    {'label': 'Nescafe',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '297.63',
#     'ytl': '1191.84',
#     'xbr': '357.53',
#     'ybr': '1212.20',
#     'z_order': '0'},
#    {'label': 'Жокей',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '441.76',
#     'ytl': '1546.10',
#     'xbr': '523.01',
#     'ybr': '1618.40',
#     'z_order': '0'},
#    {'label': 'Tchibo',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '0.27',
#     'ytl': '2463.47',
#     'xbr': '94.86',
#     'ybr': '2546.94',
#     'z_order': '0'},
#    {'label': 'Nescafe',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '570.64',
#     'ytl': '1198.07',
#     'xbr': '641.09',
#     'ybr': '1222.12',
#     'z_order': '0'},
#    {'label': 'Красная цена coffee',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '64.02',
#     'ytl': '2879.22',
#     'xbr': '187.68',
#     'ybr': '2953.93',
#     'z_order': '0'},
#    {'label': 'Nescafe',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '468.73',
#     'ytl': '2509.00',
#     'xbr': '611.50',
#     'ybr': '2570.23',
#     'z_order': '0'},
#    {'label': 'MONARCH',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '284.84',
#     'ytl': '595.39',
#     'xbr': '394.27',
#     'ybr': '645.47',
#     'z_order': '0'},
#    {'label': 'Fresco',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '1471.36',
#     'ytl': '156.89',
#     'xbr': '1535.77',
#     'ybr': '247.06',
#     'z_order': '0'},
#    {'label': 'Jacobs',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '829.50',
#     'ytl': '627.16',
#     'xbr': '931.30',
#     'ybr': '686.42',
#     'z_order': '0'},
#    {'label': 'MONARCH',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '936.04',
#     'ytl': '1851.09',
#     'xbr': '1124.10',
#     'ybr': '1946.40',
#     'z_order': '0'},
#    {'label': 'Черная Карта',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '1154.71',
#     'ytl': '1876.08',
#     'xbr': '1315.46',
#     'ybr': '2095.56',
#     'z_order': '0'},
#    {'label': 'Красная цена coffee',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '407.94',
#     'ytl': '3020.91',
#     'xbr': '531.59',
#     'ybr': '3145.85',
#     'z_order': '0'},
#    {'label': 'Migel',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '802.34',
#     'ytl': '2980.50',
#     'xbr': '972.40',
#     'ybr': '3069.34',
#     'z_order': '0'},
#    {'label': 'Nescafe',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '945.85',
#     'ytl': '2418.86',
#     'xbr': '1071.40',
#     'ybr': '2459.70',
#     'z_order': '0'},
#    {'label': 'Jacobs',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '0.00',
#     'ytl': '1936.70',
#     'xbr': '144.94',
#     'ybr': '2005.33',
#     'z_order': '0'},
#    {'label': 'Fresco',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '1604.01',
#     'ytl': '159.46',
#     'xbr': '1668.41',
#     'ybr': '249.62',
#     'z_order': '0'},
#    {'label': 'Красная цена coffee',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '267.54',
#     'ytl': '3002.88',
#     'xbr': '366.72',
#     'ybr': '3109.79',
#     'z_order': '0'},
#    {'label': 'MONARCH',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '694.07',
#     'ytl': '623.71',
#     'xbr': '803.50',
#     'ybr': '673.79',
#     'z_order': '0'},
#    {'label': 'MILAGRO',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '0.00',
#     'ytl': '1137.27',
#     'xbr': '83.36',
#     'ybr': '1165.09',
#     'z_order': '0'},
#    {'label': 'Красная цена coffee',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '608.87',
#     'ytl': '3000.30',
#     'xbr': '741.54',
#     'ybr': '3105.92',
#     'z_order': '0'},
#    {'label': 'Красная цена coffee',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '58.87',
#     'ytl': '3023.49',
#     'xbr': '199.27',
#     'ybr': '3148.43',
#     'z_order': '0'},
#    {'label': 'MONARCH',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '1224.06',
#     'ytl': '628.90',
#     'xbr': '1341.70',
#     'ybr': '692.40',
#     'z_order': '0'},
#    {'label': 'Egoiste',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '1712.23',
#     'ytl': '187.80',
#     'xbr': '1790.81',
#     'ybr': '225.16',
#     'z_order': '0'},
#    {'label': 'Nescafe',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '418.76',
#     'ytl': '1172.00',
#     'xbr': '489.20',
#     'ybr': '1196.05',
#     'z_order': '0'},
#    {'label': 'Venetto',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '1448.19',
#     'ytl': '1598.92',
#     'xbr': '1497.90',
#     'ybr': '1669.30',
#     'z_order': '0'},
#    {'label': 'Nescafe',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '1376.90',
#     'ytl': '1188.17',
#     'xbr': '1450.54',
#     'ybr': '1215.41',
#     'z_order': '0'},
#    {'label': 'МОСКОВСКАЯ КОФЕЙНЯ НА ПАЯХ',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '1319.49',
#     'ytl': '132.14',
#     'xbr': '1394.63',
#     'ybr': '184.73',
#     'z_order': '0'},
#    {'label': 'Nescafe',
#     'occluded': '0',
#     'source': 'manual',
#     'xtl': '1586.66',
#     'ytl': '2368.40',
#     'xbr': '1738.00',
#     'ybr': '2445.73',
#     'z_order': '0'}],
#   'points': []}}

# %%
from PIL import Image, ImageDraw
import os

def get_unique_filename(file_path):
    base, extension = os.path.splitext(file_path)
    counter = 1
    while os.path.exists(file_path):
        file_path = f"{base}_{counter}{extension}"
        counter += 1
    return file_path

def save_crop(img_name, bbox_orig, destination):
    image_path = img_name
    original_image = Image.open(image_path)
    cropped_image = original_image.crop(bbox_orig)
    cropped_image.save(destination)

# %%
for image_data in images_data:
    checked = 0
    for box_data in image_data['children']['box']:
        box_bbox = [int(float(box_data['xtl'])), int(float(box_data['ytl'])), 
                    int(float(box_data['xbr'])), int(float(box_data['ybr']))]
        destination = get_unique_filename(f'data/{folder_name}/cropped/' + 'cropped_' + image_data['attributes']['name'])
        save_crop(f'data/{folder_name}/images/' + image_data['attributes']['name'], box_bbox, destination)
        box_data['cropped_name'] = destination.split('/')[-1]
        checked = 1
    image_data['checked'] = checked

# %%
len(images_data)
# Out:
# 175

# %%
import openpyxl
from openpyxl.drawing.image import Image
from openpyxl.utils import get_column_letter
from copy import deepcopy
from PIL import Image as PILImage

def pixels_to_width_units(pixels):
    return pixels / 7

def get_image_size_with_aspect_ratio(image_path, max_width):
    with PILImage.open(image_path) as img:
        original_width, original_height = img.size
        if original_width > max_width:
            scaling_factor = max_width / original_width
            new_width = max_width
            new_height = original_height * scaling_factor
            return new_width, new_height
        else:
            return original_width, original_height

wb = openpyxl.Workbook()
ws = wb.active

result = []
max_points = 0
copied_data = deepcopy(images_data)

for image_data in copied_data:
    label_groups = {}
    for changed_point in image_data['children']['box']:
        # if changed_point['label'] != 'ignore':
        label = changed_point['label']
        if label not in label_groups:
            label_groups[label] = []
        label_groups[label].append(changed_point)

    for label, points in label_groups.items():
        image_file_paths = []
        for point in points:
            local_file_path = f"data/{folder_name}/cropped/{point['cropped_name']}"
            image_file_paths.append(local_file_path)

        column = [label, None, None, image_data['attributes']['id'], image_data['attributes']['name'], len(points)] + image_file_paths

        if len(points) > max_points:
            max_points = len(points)

        result.append(column)

result.sort(key=lambda x: x[0])

headers = ['Название', 'фото эталон', 'task id', 'id фото в task', 'название фото', 'количество точек на фото'] + [f'фото{x}' for x in range(1, max_points + 1)]
ws.append(headers)

max_image_widths = [0] * max_points

for row, data in enumerate(result, start=2):
    max_height_in_row = 0
    for col, cell_value in enumerate(data, start=1):
        if isinstance(cell_value, str) and cell_value.startswith(f"data/{folder_name}/cropped/"):
            img_width, img_height = get_image_size_with_aspect_ratio(cell_value, 200) 
            img = Image(cell_value)
            img.width, img.height = img_width, img_height
            max_height_in_row = max(max_height_in_row, img.height)
            ws.add_image(img, get_column_letter(col) + str(row))

            image_col_index = col - 6
            if 0 <= image_col_index < len(max_image_widths):
                max_image_widths[image_col_index] = max(max_image_widths[image_col_index], img_width)
        else:
            ws.cell(row=row, column=col, value=cell_value)

    if max_height_in_row > 0:
        ws.row_dimensions[row].height = max_height_in_row * 0.75

for i, max_width in enumerate(max_image_widths, start=6):
    if max_width > 0:
        ws.column_dimensions[get_column_letter(i)].width = pixels_to_width_units(max_width)

ws.column_dimensions['A'].width = 40
ws.column_dimensions['E'].width = 20

wb.save(f'data/{folder_name}/output.xlsx')
